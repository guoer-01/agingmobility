# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap,ListedColormap
import matplotlib.cm as cm
import pandas as pd
import numpy as np

# %%
#17% 21% 24%
nowrate= 0.17 #sum(df_census['above_65'])/sum(df_census['population_by_age'])

growthrate30=0.21/nowrate

growthrate60=0.24/nowrate

# %%
df_census = pd.read_csv('D:/main/1_research/P10_Mobility/p10_aging mobility/new data/census/all_census_data_with_location.csv')

# %%
df_census_proj=df_census[['census_block_group','percent_above_65']]
df_census_proj['2019_is_old']=df_census_proj.apply(lambda x: 1 if x['percent_above_65']>0.5 else 0,axis=1)
df_census_proj['2030_percent_above_65']=df_census_proj['percent_above_65']*growthrate30
df_census_proj['2030_is_old']=df_census_proj.apply(lambda x: 1 if x['2030_percent_above_65']>0.5 else 0,axis=1)
df_census_proj['2060_percent_above_65']=df_census_proj['percent_above_65']*growthrate60
df_census_proj['2060_is_old']=df_census_proj.apply(lambda x: 1 if x['2060_percent_above_65']>0.5 else 0,axis=1)
# Out:
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3013625533.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['2019_is_old']=df_census_proj.apply(lambda x: 1 if x['percent_above_65']>0.5 else 0,axis=1)
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3013625533.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['2030_percent_above_65']=df_census_proj['percent_above_65']*growthrate30
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3013625533.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['2030_is_old']=df_census_proj.apply(lambda x: 1 if x['2030_percent_above_65']>0.5 else 0,axis=1)
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3013625533.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['2060_percent_above_65']=df_census_proj['percent_above_65']*growthrate60
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3013625533.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['2060_is_old']=df_census_proj.apply(lambda x: 1 if x['2060_percent_above_65']>0.5 else 0,axis=1)

# %%
df_census_proj
# Out:
#         census_block_group  percent_above_65  2019_is_old  \
# 0              10010201001          0.036242            0
# 1              10010201002          0.114625            0
# 2              10010202001          0.161458            0
# 3              10010202002          0.094660            0
# 4              10010203001          0.134095            0
# ...                    ...               ...          ...
# 220328        721537506011          0.226927            0
# 220329        721537506012          0.107658            0
# 220330        721537506013          0.057741            0
# 220331        721537506021          0.220449            0
# 220332        721537506022          0.441576            0
#
#         2030_percent_above_65  2030_is_old  2060_percent_above_65  2060_is_old
# 0                    0.044769            0               0.051165            0
# 1                    0.141595            0               0.161823            0
# 2                    0.199449            0               0.227941            0
# 3                    0.116933            0               0.133638            0
# 4                    0.165646            0               0.189310            0
# ...                       ...          ...                    ...          ...
# 220328               0.280322            0               0.320368            0
# 220329               0.132989            0               0.151988            0
# 220330               0.071327            0               0.081516            0
# 220331               0.272319            0               0.311222            0
# 220332               0.545476            1               0.623402            1
#
# [220333 rows x 7 columns]

# %%
dict_state={'1': 'AL', '2': 'AK', '4': 'AZ', '5': 'AR', '6': 'CA', '8': 'CO', '9': 'CT', '10': 'DE', '11': 'DC', '12': 'FL', '13': 'GA', '15': 'HI', '16': 'ID',
            '17': 'IL', '18': 'IN', '19': 'IA', '20': 'KS', '21': 'KY', '22': 'LA', '23': 'ME', '24': 'MD', '25': 'MA', '26': 'MI', '27': 'MN', '28': 'MS', '29': 'MO',
            '30': 'MT', '31': 'NE', '32': 'NV', '33': 'NH', '34': 'NJ', '35': 'NM', '36': 'NY', '37': 'NC', '38': 'ND', '39': 'OH', '40': 'OK', '41': 'OR', '42': 'PA', 
            '44': 'RI', '45': 'SC', '46': 'SD', '47': 'TN', '48': 'TX', '49': 'UT', '50': 'VT', '51': 'VA', '53': 'WA', '54': 'WV', '55': 'WI', '56': 'WY', '60': 'AS', 
            '66': 'GU', '69': 'MP', '72': 'PR', '74': 'UM', '78': 'VI'}    

df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype(str)

df_census_proj['state']=df_census_proj.apply(lambda x: dict_state[x['census_block_group'][:2]] if len(x['census_block_group'])==12 
                                                else dict_state[x['census_block_group'][:1]],
                                                axis=1)

df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype('int64')
# Out:
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3833134942.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype(str)
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3833134942.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['state']=df_census_proj.apply(lambda x: dict_state[x['census_block_group'][:2]] if len(x['census_block_group'])==12
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\3833134942.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype('int64')

# %%
df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype(str)
df_census_proj['countyfip']=df_census_proj.apply(lambda x: x['census_block_group'][:5] if len(x['census_block_group'])==12 
                                                else '0'+x['census_block_group'][:4],
                                                axis=1)
df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype('int64')
# Out:
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\4060443898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype(str)
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\4060443898.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['countyfip']=df_census_proj.apply(lambda x: x['census_block_group'][:5] if len(x['census_block_group'])==12
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\4060443898.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj['census_block_group']=df_census_proj['census_block_group'].astype('int64')

# %%
for pre in ['2019','2030','2060']:
    df_census_proj[pre+'_age']=df_census_proj.apply(lambda x: 'greater than 0.5' if x[pre+'_is_old']==1 else 'less than or equal to 0.5', axis=1)
# Out:
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\575457998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj[pre+'_age']=df_census_proj.apply(lambda x: 'greater than 0.5' if x[pre+'_is_old']==1 else 'less than or equal to 0.5', axis=1)
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\575457998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj[pre+'_age']=df_census_proj.apply(lambda x: 'greater than 0.5' if x[pre+'_is_old']==1 else 'less than or equal to 0.5', axis=1)
# C:\Users\Linao\AppData\Local\Temp\ipykernel_39328\575457998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_census_proj[pre+'_age']=df_census_proj.apply(lambda x: 'greater than 0.5' if x[pre+'_is_old']==1 else 'less than or equal to 0.5', axis=1)

# %%
df_census_proj
# Out:
#         census_block_group  percent_above_65  2019_is_old  \
# 0              10010201001          0.036242            0
# 1              10010201002          0.114625            0
# 2              10010202001          0.161458            0
# 3              10010202002          0.094660            0
# 4              10010203001          0.134095            0
# ...                    ...               ...          ...
# 220328        721537506011          0.226927            0
# 220329        721537506012          0.107658            0
# 220330        721537506013          0.057741            0
# 220331        721537506021          0.220449            0
# 220332        721537506022          0.441576            0
#
#         2030_percent_above_65  2030_is_old  2060_percent_above_65  \
# 0                    0.044769            0               0.051165
# 1                    0.141595            0               0.161823
# 2                    0.199449            0               0.227941
# 3                    0.116933            0               0.133638
# 4                    0.165646            0               0.189310
# ...                       ...          ...                    ...
# 220328               0.280322            0               0.320368
# 220329               0.132989            0               0.151988
# 220330               0.071327            0               0.081516
# 220331               0.272319            0               0.311222
# 220332               0.545476            1               0.623402
#
#         2060_is_old state countyfip                   2019_age  \
# 0                 0    AL     01001  less than or equal to 0.5
# 1                 0    AL     01001  less than or equal to 0.5
# 2                 0    AL     01001  less than or equal to 0.5
# 3                 0    AL     01001  less than or equal to 0.5
# 4                 0    AL     01001  less than or equal to 0.5
# ...             ...   ...       ...                        ...
# 220328            0    PR     72153  less than or equal to 0.5
# 220329            0    PR     72153  less than or equal to 0.5
# 220330            0    PR     72153  less than or equal to 0.5
# 220331            0    PR     72153  less than or equal to 0.5
# 220332            1    PR     72153  less than or equal to 0.5
#
#                          2030_age                   2060_age
# 0       less than or equal to 0.5  less than or equal to 0.5
# 1       less than or equal to 0.5  less than or equal to 0.5
# 2       less than or equal to 0.5  less than or equal to 0.5
# 3       less than or equal to 0.5  less than or equal to 0.5
# 4       less than or equal to 0.5  less than or equal to 0.5
# ...                           ...                        ...
# 220328  less than or equal to 0.5  less than or equal to 0.5
# 220329  less than or equal to 0.5  less than or equal to 0.5
# 220330  less than or equal to 0.5  less than or equal to 0.5
# 220331  less than or equal to 0.5  less than or equal to 0.5
# 220332           greater than 0.5           greater than 0.5
#
# [220333 rows x 12 columns]

# %%
##state-level
#new measure of fairindex based on distribution difference


dict_state={'1': 'AL', '2': 'AK', '4': 'AZ', '5': 'AR', '6': 'CA', '8': 'CO', '9': 'CT', '10': 'DE', '11': 'DC', '12': 'FL', '13': 'GA', '15': 'HI', '16': 'ID',
            '17': 'IL', '18': 'IN', '19': 'IA', '20': 'KS', '21': 'KY', '22': 'LA', '23': 'ME', '24': 'MD', '25': 'MA', '26': 'MI', '27': 'MN', '28': 'MS', '29': 'MO',
            '30': 'MT', '31': 'NE', '32': 'NV', '33': 'NH', '34': 'NJ', '35': 'NM', '36': 'NY', '37': 'NC', '38': 'ND', '39': 'OH', '40': 'OK', '41': 'OR', '42': 'PA', 
            '44': 'RI', '45': 'SC', '46': 'SD', '47': 'TN', '48': 'TX', '49': 'UT', '50': 'VT', '51': 'VA', '53': 'WA', '54': 'WV', '55': 'WI', '56': 'WY', '60': 'AS', 
            '66': 'GU', '69': 'MP', '72': 'PR', '74': 'UM', '78': 'VI'}

col=['census_block_group','ParentType','num_accessible_facility','demand_ratios','demand_met_in_local']

listParentType=['Health Care Services',
                 'Pharmaceutical and Medical Supply Stores',
                 'Grocery and Food Supply',
                 'Social Assistance',
                 'Transportation Services',
                 'Home Health Care Services',
                 'Financial Services',
                 'Legal Services',
                 'Housing and Real Estate',
                 'Personal Care Services',
                 'Utility Services',
                 'Retail Stores for Basic Needs']

abb_dict={'Health Care Services':'HCS','Grocery and Food Supply':'GFS', 'Housing and Real Estate':'HRE'}
listParentType1=abb_dict.keys()


homoDistDiffFairList=[]

for pre in ['2019','2030','2060']:
    for key in listParentType1: 

        homoPath='D:/main/1_research/P10_Mobility/p10_aging mobility/results_all_states/allStatesByParentType/homo_supply_demand/'+key+'.csv'

        dfHomo=pd.read_csv(homoPath,usecols=col)

        dfHomo['census_block_group']=dfHomo['census_block_group'].astype(str)
        dfHomo['statefip']=dfHomo.apply(lambda x: x['census_block_group'][0:2] if len(x['census_block_group'])==12 
                                         else x['census_block_group'][0:1],axis=1)
        dfHomo['census_block_group']=dfHomo['census_block_group'].astype('int64')

        dfHomo=pd.merge(dfHomo, df_census_proj[['census_block_group',pre+'_age']])


        print('read data_'+key+'_'+pre)

        for fip in dict_state.keys():
            state=dict_state[fip]
            #print(state)
        #homo
            df_st=dfHomo[dfHomo['statefip']==fip]     

            #distribution-diff fairindex
            if len(df_st)>0:
                numold=len(df_st[(df_st[pre+'_age']=='greater than 0.5')&(df_st['demand_met_in_local']<=1)])
                if numold>0:     
                    sumfair=0
                    for i in range(9):
                        thres=np.percentile(df_st[(df_st[pre+'_age']!='greater than 0.5')&
                                                (df_st['demand_met_in_local']<=1)]['demand_met_in_local'],i*10+10)
                        numGood=len(df_st[(df_st['demand_met_in_local']>=thres)&(df_st[pre+'_age']=='greater than 0.5')&
                                            (df_st['demand_met_in_local']<=1)])     
                        fairindex=numGood/numold-(1-(i*10+10)/100)
                        sumfair += fairindex

                    FairIndex=sumfair/4.5
                    homoDistDiffFairList.append((pre,key,state,FairIndex,'5 miles'))


        print('done'+key+'_'+pre)    
    
    


    
ProjDDFairDF=pd.DataFrame(homoDistDiffFairList,columns=['year','parentType','state','FairIndex','coverage'])
# Out:
# read data_Health Care Services_2019
# doneHealth Care Services_2019
# read data_Grocery and Food Supply_2019
# doneGrocery and Food Supply_2019
# read data_Housing and Real Estate_2019
# doneHousing and Real Estate_2019
# read data_Health Care Services_2030
# doneHealth Care Services_2030
# read data_Grocery and Food Supply_2030
# doneGrocery and Food Supply_2030
# read data_Housing and Real Estate_2030
# doneHousing and Real Estate_2030
# read data_Health Care Services_2060
# doneHealth Care Services_2060
# read data_Grocery and Food Supply_2060
# doneGrocery and Food Supply_2060
# read data_Housing and Real Estate_2060
# doneHousing and Real Estate_2060

# %%
##US-level
#new measure of fairindex based on distribution difference


col=['census_block_group','ParentType','num_accessible_facility','demand_ratios','demand_met_in_local']


abb_dict={'Health Care Services':'HCS','Grocery and Food Supply':'GFS', 'Housing and Real Estate':'HRE'}
listParentType1=abb_dict.keys()


homoDistDiffFairList=[]

for pre in ['2019','2030','2060']:
    for key in listParentType1: 

        homoPath='D:/main/1_research/P10_Mobility/p10_aging mobility/results_all_states/allStatesByParentType/homo_supply_demand/'+key+'.csv'

        dfHomo=pd.read_csv(homoPath,usecols=col)

        dfHomo['census_block_group']=dfHomo['census_block_group'].astype(str)
        dfHomo['statefip']=dfHomo.apply(lambda x: x['census_block_group'][0:2] if len(x['census_block_group'])==12 
                                         else x['census_block_group'][0:1],axis=1)
        dfHomo['census_block_group']=dfHomo['census_block_group'].astype('int64')

        dfHomo=pd.merge(dfHomo, df_census_proj[['census_block_group',pre+'_age']])


        print('read data_'+key+'_'+pre)


        #homo
        df_st=dfHomo

        #distribution-diff fairindex
        if len(df_st)>0:
            numold=len(df_st[(df_st[pre+'_age']=='greater than 0.5')&(df_st['demand_met_in_local']<=1)])
            if numold>0:     
                sumfair=0
                for i in range(9):
                    thres=np.percentile(df_st[(df_st[pre+'_age']!='greater than 0.5')&
                                            (df_st['demand_met_in_local']<=1)]['demand_met_in_local'],i*10+10)
                    numGood=len(df_st[(df_st['demand_met_in_local']>=thres)&(df_st[pre+'_age']=='greater than 0.5')&
                                        (df_st['demand_met_in_local']<=1)])     
                    fairindex=numGood/numold-(1-(i*10+10)/100)
                    sumfair += fairindex

                FairIndex=sumfair/4.5
                homoDistDiffFairList.append((pre,key,'US',FairIndex,'5 miles'))


        print('done'+key+'_'+pre)    
    
    


    
ProjDDFairDF_US=pd.DataFrame(homoDistDiffFairList,columns=['year','parentType','state','FairIndex','coverage'])
# Out:
# read data_Health Care Services_2019
# doneHealth Care Services_2019
# read data_Grocery and Food Supply_2019
# doneGrocery and Food Supply_2019
# read data_Housing and Real Estate_2019
# doneHousing and Real Estate_2019
# read data_Health Care Services_2030
# doneHealth Care Services_2030
# read data_Grocery and Food Supply_2030
# doneGrocery and Food Supply_2030
# read data_Housing and Real Estate_2030
# doneHousing and Real Estate_2030
# read data_Health Care Services_2060
# doneHealth Care Services_2060
# read data_Grocery and Food Supply_2060
# doneGrocery and Food Supply_2060
# read data_Housing and Real Estate_2060
# doneHousing and Real Estate_2060

# %%
##county-level
#new measure of fairindex based on distribution difference




col=['census_block_group','ParentType','num_accessible_facility','demand_ratios','demand_met_in_local']


abb_dict={'Health Care Services':'HCS','Grocery and Food Supply':'GFS', 'Housing and Real Estate':'HRE'}
listParentType1=abb_dict.keys()


homoDistDiffFairList=[]

for pre in ['2019','2030','2060']:
    for key in listParentType1: 

        homoPath='D:/main/1_research/P10_Mobility/p10_aging mobility/results_all_states/allStatesByParentType/homo_supply_demand/'+key+'.csv'

        dfHomo=pd.read_csv(homoPath,usecols=col)

        dfHomo['census_block_group']=dfHomo['census_block_group'].astype(str)
        dfHomo['countyfip']=dfHomo.apply(lambda x: x['census_block_group'][0:5] if len(x['census_block_group'])==12 
                                         else '0'+x['census_block_group'][0:4],axis=1)
        dfHomo['census_block_group']=dfHomo['census_block_group'].astype('int64')

        dfHomo=pd.merge(dfHomo, df_census_proj[['census_block_group',pre+'_age']])


        print('read data_'+key+'_'+pre)

        for fip in dfHomo['countyfip'].unique():For
            
            #print(state)
        #homo
            df_st=dfHomo[dfHomo['countyfip']==fip]     

            #distribution-diff fairindex
            if len(df_st)>0:
                numold=len(df_st[(df_st[pre+'_age']=='greater than 0.5')&(df_st['demand_met_in_local']<=1)])
                if numold>0:     
                    sumfair=0
                    if len(df_st[(df_st[pre+'_age']!='greater than 0.5')&(df_st['demand_met_in_local']<=1)])>0:
                        for i in range(9):
                            thres=np.percentile(df_st[(df_st[pre+'_age']!='greater than 0.5')&
                                                    (df_st['demand_met_in_local']<=1)]['demand_met_in_local'],i*10+10)
                            numGood=len(df_st[(df_st['demand_met_in_local']>=thres)&(df_st[pre+'_age']=='greater than 0.5')&
                                                (df_st['demand_met_in_local']<=1)])     
                            fairindex=numGood/numold-(1-(i*10+10)/100)
                            sumfair += fairindex
                        FairIndex=sumfair/4.5
                        homoDistDiffFairList.append((pre,key,fip,FairIndex,'5 miles'))


        print('done'+key+'_'+pre)    
    
    


    
ProjDDFairDF_county=pd.DataFrame(homoDistDiffFairList,columns=['year','parentType','countyfip','FairIndex','coverage'])
# Out:
# read data_Health Care Services_2019
# doneHealth Care Services_2019
# read data_Grocery and Food Supply_2019
# doneGrocery and Food Supply_2019
# read data_Housing and Real Estate_2019
# doneHousing and Real Estate_2019
# read data_Health Care Services_2030
# doneHealth Care Services_2030
# read data_Grocery and Food Supply_2030
# doneGrocery and Food Supply_2030
# read data_Housing and Real Estate_2030
# doneHousing and Real Estate_2030
# read data_Health Care Services_2060
# doneHealth Care Services_2060
# read data_Grocery and Food Supply_2060
# doneGrocery and Food Supply_2060
# read data_Housing and Real Estate_2060
# doneHousing and Real Estate_2060

# %%
df_census_proj
# Out:
#         census_block_group  percent_above_65  2019_is_old  \
# 0              10010201001          0.036242            0
# 1              10010201002          0.114625            0
# 2              10010202001          0.161458            0
# 3              10010202002          0.094660            0
# 4              10010203001          0.134095            0
# ...                    ...               ...          ...
# 220328        721537506011          0.226927            0
# 220329        721537506012          0.107658            0
# 220330        721537506013          0.057741            0
# 220331        721537506021          0.220449            0
# 220332        721537506022          0.441576            0
#
#         2030_percent_above_65  2030_is_old  2060_percent_above_65  \
# 0                    0.044769            0               0.051165
# 1                    0.141595            0               0.161823
# 2                    0.199449            0               0.227941
# 3                    0.116933            0               0.133638
# 4                    0.165646            0               0.189310
# ...                       ...          ...                    ...
# 220328               0.280322            0               0.320368
# 220329               0.132989            0               0.151988
# 220330               0.071327            0               0.081516
# 220331               0.272319            0               0.311222
# 220332               0.545476            1               0.623402
#
#         2060_is_old state countyfip                   2019_age  \
# 0                 0    AL     01001  less than or equal to 0.5
# 1                 0    AL     01001  less than or equal to 0.5
# 2                 0    AL     01001  less than or equal to 0.5
# 3                 0    AL     01001  less than or equal to 0.5
# 4                 0    AL     01001  less than or equal to 0.5
# ...             ...   ...       ...                        ...
# 220328            0    PR     72153  less than or equal to 0.5
# 220329            0    PR     72153  less than or equal to 0.5
# 220330            0    PR     72153  less than or equal to 0.5
# 220331            0    PR     72153  less than or equal to 0.5
# 220332            1    PR     72153  less than or equal to 0.5
#
#                          2030_age                   2060_age
# 0       less than or equal to 0.5  less than or equal to 0.5
# 1       less than or equal to 0.5  less than or equal to 0.5
# 2       less than or equal to 0.5  less than or equal to 0.5
# 3       less than or equal to 0.5  less than or equal to 0.5
# 4       less than or equal to 0.5  less than or equal to 0.5
# ...                           ...                        ...
# 220328  less than or equal to 0.5  less than or equal to 0.5
# 220329  less than or equal to 0.5  less than or equal to 0.5
# 220330  less than or equal to 0.5  less than or equal to 0.5
# 220331  less than or equal to 0.5  less than or equal to 0.5
# 220332           greater than 0.5           greater than 0.5
#
# [220333 rows x 12 columns]

# %%
ppath='D:\main\1_research\P10_Mobility\p10_aging mobility\results_all_states\allStatesByParentType\projection'
df_census_proj.to_csv(r'D:\main\1_research\P10_Mobility\p10_aging mobility\results_all_states\allStatesByParentType\projection\df_census_proj.csv')

# %%
ProjDDFairDF['num_old_cbg']=ProjDDFairDF.apply( lambda x: sum( df_census_proj[df_census_proj['state']==x['state']][x['year']+'_is_old']),axis=1)
ProjDDFairDF['num_cbg']=ProjDDFairDF.apply( lambda x: len( df_census_proj[df_census_proj['state']==x['state']]),axis=1)

# %%
ProjDDFairDF
# Out:
#      year               parentType state  FairIndex coverage  num_old_cbg  \
# 0    2019     Health Care Services    AL   0.311111  5 miles           10
# 1    2019     Health Care Services    AZ   0.075426  5 miles          274
# 2    2019     Health Care Services    AR   0.059829  5 miles           13
# 3    2019     Health Care Services    CA  -0.071835  5 miles          221
# 4    2019     Health Care Services    CO   0.197531  5 miles           18
# ..    ...                      ...   ...        ...      ...          ...
# 447  2060  Housing and Real Estate    WA  -0.160819  5 miles          153
# 448  2060  Housing and Real Estate    WV   0.229314  5 miles           48
# 449  2060  Housing and Real Estate    WI   0.111111  5 miles          116
# 450  2060  Housing and Real Estate    WY   0.000000  5 miles            2
# 451  2060  Housing and Real Estate    PR   0.243187  5 miles          117
#
#      num_cbg
# 0       3438
# 1       4178
# 2       2147
# 3      23212
# 4       3532
# ..       ...
# 447     4783
# 448     1592
# 449     4489
# 450      410
# 451     2594
#
# [452 rows x 7 columns]

# %%
ProjDDFairDF.to_csv(r'D:\main\1_research\P10_Mobility\p10_aging mobility\results_all_states\allStatesByParentType\projection\ProjDDFairDF_state.csv')

# %%
ProjDDFairDF_US['num_old_cbg']=100
ProjDDFairDF_US['num_cbg']=1000

# %%
ProjDDFairDF_US
# Out:
#    year               parentType state  FairIndex coverage  num_old_cbg  \
# 0  2019     Health Care Services    US   0.123413  5 miles          100
# 1  2019  Grocery and Food Supply    US   0.067020  5 miles          100
# 2  2019  Housing and Real Estate    US   0.193383  5 miles          100
# 3  2030     Health Care Services    US   0.096022  5 miles          100
# 4  2030  Grocery and Food Supply    US   0.018425  5 miles          100
# 5  2030  Housing and Real Estate    US   0.104055  5 miles          100
# 6  2060     Health Care Services    US   0.077575  5 miles          100
# 7  2060  Grocery and Food Supply    US   0.001660  5 miles          100
# 8  2060  Housing and Real Estate    US   0.067226  5 miles          100
#
#    num_cbg
# 0     1000
# 1     1000
# 2     1000
# 3     1000
# 4     1000
# 5     1000
# 6     1000
# 7     1000
# 8     1000

# %%
ProjDDFairDF_US.to_csv(r'D:\main\1_research\P10_Mobility\p10_aging mobility\results_all_states\allStatesByParentType\projection\ProjDDFairDF_US.csv')

# %%
a=ProjDDFairDF_US[(ProjDDFairDF_US['parentType']=='Health Care Services')&(ProjDDFairDF_US['year']=='2060')]['FairIndex'].iat[0]
b=ProjDDFairDF_US[(ProjDDFairDF_US['parentType']=='Health Care Services')&(ProjDDFairDF_US['year']=='2019')]['FairIndex'].iat[0]
print((a-b)/b)
# Out:
# -0.3714232884237125

# %%
key='Housing and Real Estate'
st='CA'
a=ProjDDFairDF[(ProjDDFairDF['parentType']==key)&(ProjDDFairDF['year']=='2060')&(ProjDDFairDF['state']==st)]['FairIndex'].iat[0]
b=ProjDDFairDF[(ProjDDFairDF['parentType']==key)&(ProjDDFairDF['year']=='2019')&(ProjDDFairDF['state']==st)]['FairIndex'].iat[0]
c=ProjDDFairDF[(ProjDDFairDF['parentType']==key)&(ProjDDFairDF['year']=='2030')&(ProjDDFairDF['state']==st)]['FairIndex'].iat[0]
print((a-c)/c)
print((a-b)/b)
print(a,c,b)
# Out:
# 0.7983539094650215
# -8.551724137931055
# -0.11111111111111116 -0.06178489702517162 0.014713343480466736

# %%
ProjDDFairDF_county['num_old_cbg']=ProjDDFairDF_county.apply( lambda x: sum( df_census_proj[df_census_proj['countyfip']==x['countyfip']][x['year']+'_is_old']),axis=1)
ProjDDFairDF_county['num_cbg']=ProjDDFairDF_county.apply( lambda x: len( df_census_proj[df_census_proj['countyfip']==x['countyfip']]),axis=1)

# %%
ProjDDFairDF_county['Ratio of old CBGs']=ProjDDFairDF_county['num_old_cbg']/ProjDDFairDF_county['num_cbg']

# %%
ProjDDFairDF_county
# Out:
#       year               parentType countyfip  FairIndex coverage  \
# 0     2019     Health Care Services     01003  -0.037037  5 miles
# 1     2019     Health Care Services     01015  -0.777778  5 miles
# 2     2019     Health Care Services     01073   0.777778  5 miles
# 3     2019     Health Care Services     01077   0.333333  5 miles
# 4     2019     Health Care Services     01089   0.555556  5 miles
# ...    ...                      ...       ...        ...      ...
# 8709  2060  Housing and Real Estate     72131  -0.777778  5 miles
# 8710  2060  Housing and Real Estate     72137  -0.111111  5 miles
# 8711  2060  Housing and Real Estate     72139   0.407407  5 miles
# 8712  2060  Housing and Real Estate     72145  -0.555556  5 miles
# 8713  2060  Housing and Real Estate     72153   0.111111  5 miles
#
#       num_old_cbg  num_cbg  Ratio of old CBGs
# 0               3       94           0.031915
# 1               1       91           0.010989
# 2               1      518           0.001931
# 3               1       73           0.013699
# 4               1      191           0.005236
# ...           ...      ...                ...
# 8709            1       25           0.040000
# 8710            1       60           0.016667
# 8711            3       42           0.071429
# 8712            2       38           0.052632
# 8713            2       28           0.071429
#
# [8714 rows x 8 columns]

# %%
ProjDDFairDF_county.to_csv(r'D:\main\1_research\P10_Mobility\p10_aging mobility\results_all_states\allStatesByParentType\projection\ProjDDFairDF_county.csv')

# %%
fig, ax=plt.subplots(2,3,constrained_layout=True, figsize=(9, 7))#
abb_dict={'Health Care Services':'HCS','Grocery and Food Supply':'GFS', 'Housing and Real Estate':'HRE'}


color_dict={'Health Care Services':'#B3D8D5','Grocery and Food Supply':'#E7C1D7', 'Housing and Real Estate':'#F8D8B9'}
mainPType=color_dict.keys()
state_color_dict={'US':'#98A3CA','FL':'skyblue', 'AZ':'#E6BCB0','CA':'#F2DB96'}

year_dict={'2019':'#7FB2D5','2030':'#AF9BC9', '2060':'#E6BCB0'}

k=30
dfD=ProjDDFairDF[ProjDDFairDF['num_old_cbg']>=k]

        
#US FL AZ CA outcome

df_state_us=pd.concat([ProjDDFairDF,ProjDDFairDF_US])
df_state_us=df_state_us[df_state_us['state'].isin(['US','FL','AZ','CA'])]


for j, key in enumerate(mainPType): 
    
    s=sns.lineplot(x='year',y='FairIndex',data=df_state_us[df_state_us['parentType']==key],ax=ax[0][j],hue='state',style='state',
                   palette=state_color_dict,hue_order=['US','FL','AZ','CA'],markers=True)
    s.set_title(key)
    
    ax[0, j].legend(title='',fontsize='small')
    
    ax[0, j].set_ylim([-0.25, 0.25])
    
    ax[0, j].set_xlabel('')
    
    if j>0:
        ax[0, j].set_ylabel('')
        ax[0, j].set_yticks([])
    else:
        ax[0, j].set_yticks([-0.2,-0.1,0,0.1,0.2])
        ax[0, j].set_ylabel(r'$\Delta \bar F$',usetex=True)
        
for j, key in enumerate(mainPType): #key='Health Care Services'
    #
    dfD=ProjDDFairDF_county
    s=sns.scatterplot(x='Ratio of old CBGs',y='FairIndex',hue='year',data=dfD[dfD['parentType']==key],ax=ax[1][j],alpha=0.8,s=20,
                        palette=year_dict,style='year', markers={'2019': 'o', '2030': 's', '2060': '^'})
    s.set_title(key)
    ax[1, j].legend(title='',fontsize='small')
    ax[1, j].set_ylim([-1.15, 1.15])

    for pre in ['2019','2030','2060']:
        sn=sns.regplot(data=dfD[(dfD['parentType']==key)&(dfD['year']==pre)], x="Ratio of old CBGs", y='FairIndex',
                       color=year_dict[pre],scatter=False, ax=ax[1][j])
    if j>0:
        ax[1, j].set_ylabel('')
        ax[1, j].set_yticks([])
    else:
        ax[1, j].set_yticks([-1.0,-0.5,0,0.5,1])
        ax[1, j].set_ylabel(r'$\Delta \bar F$',usetex=True)
        
    ax[1, j].set_xlabel('Ratio of high-aging CBGs')
# Out:
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig.savefig(prepath+'projection/fairindex_no_distribution.jpg',dpi=600)  
#缩小图例 去掉x轴标签

# %%
fig, ax=plt.subplots(1,3,constrained_layout=True, figsize=(372/72.27, 130/72.27))#
abb_dict={'Health Care Services':'HCS','Grocery and Food Supply':'GFS', 'Housing and Real Estate':'HRE'}


color_dict={'Health Care Services':'#B3D8D5','Grocery and Food Supply':'#E7C1D7', 'Housing and Real Estate':'#F8D8B9'}
mainPType=color_dict.keys()
state_color_dict={'US':'#98A3CA','FL':'skyblue', 'AZ':'#E6BCB0','CA':'#F2DB96'}

year_dict={'2019':'#7FB2D5','2030':'#AF9BC9', '2060':'#E6BCB0'}

k=30
dfD=ProjDDFairDF[ProjDDFairDF['num_old_cbg']>=k]
for j, key in enumerate(mainPType): 
    data=dfD[dfD['parentType']==key]
    sn = sns.violinplot(x='year', y='FairIndex', data=data,ax=ax[j], linewidth=0.5,inner=None,color=color_dict[key])  # inner=None 使得不显示小提琴图内部的默认内容

    for violin in sn.collections:
        violin.set_edgecolor('white')
        
    # 计算均值和标准差并叠加到图上
    for i, category in enumerate(dfD['year'].unique()):
        subset = data[data['year'] == category]['FairIndex']
        mean = subset.mean()
        std = subset.std()

        # 绘制均值
        sn.scatter(i, mean, color='red', s=4, zorder=3, label=f'{category} mean' if i == 0 else "")

        # 绘制标准差
        sn.errorbar(i, mean, yerr=std, color='black', capsize=2, fmt='none', lw=1, zorder=2)

    # 添加图例
    handles, labels = sn.get_legend_handles_labels()
    handles = handles[:1]  # 只显示一次均值图例
    labels = labels[:1]    # 只显示一次均值标签
    #sn.legend(handles, labels, title='统计信息')
    sn.set_title(key, fontsize=6)
    
    
    ax[ j].set_ylim([-0.56, 0.68])
    
    ax[j].set_xlabel('Year', fontsize=5)
    
    if j>0:
        ax[j].set_ylabel('')
        ax[ j].set_yticks([])
    else:
        ax[ j].set_yticks([-0.4,-0.2,0,0.2,0.4])
        ax[ j].set_ylabel(r'$\Delta \bar F$',usetex=True, fontsize=5)
        
    ax[j].axhline(0,color='gray',linestyle='dashed')
    ax[j].tick_params(axis='both', which='both', bottom=True, left=True, labelsize=5)

# %%
fig.savefig('D:/main/1_research/P10_Mobility/p10_aging mobility/results_all_states/allStatesByParentType/SI/{}.jpg'.format('fairindex_distribution_dynamics_projection-372pt'),dpi=600
           ,bbox_inches='tight') #b
